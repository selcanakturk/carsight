# %%
from pathlib import Path

import pandas as pd

# %%
data_path = Path("../data/processed/carsight_clean.csv")

df = pd.read_csv(data_path)

df.head()
# Out:
#                                          ilanBasligi  \
# 0  2016 AUDİ A3 SPORTBACK 1.0 TFSI BOYASIZ/DEĞİŞE...
# 1  2018 AUDİ A6 2.0 TDI QUATTRO SUNROOF MATRİX VA...
# 2       Sahibinden Audi A4 Sedan 1.8 TFSI 2011 Model
# 3  2016 AUDI A3 AMBİENTE *CAM TAVAN LED XENON HIZ...
# 4  Sahibinden Audi A3 Sportback 1.6 TDI S-Line 20...
#
#                         adres              il  fiyat(TRY)    ilanID  \
# 0        Aşağısoku Mh. Merkez            Bolu     1169000  27812680
# 1     Güneşevler Mh. Altındağ          Ankara     2450000  28816234
# 2          Burmalı Mh. Merkez  Afyonkarahisar      750000  28781662
# 3          Ilıca Mh. Manavgat         Antalya     1195000  28731117
# 4  Uğur Mumcu Mh. Yenimahalle          Ankara      822000  28393351
#
#       ilanTarihi marka seri                            model  kilometre(Km)  \
# 0  07 Nisan 2025  Audi   A3    A3 Sportback 1.0 TFSI Dynamic       120000.0
# 1  07 Nisan 2025  Audi   A6         A6 Sedan 2.0 TDI Quattro       136000.0
# ...

# %%
df[["kilometre(Km)", "yıl", "fiyat(TRY)"]].dtypes
# Out:
# kilometre(Km)    float64
# yıl                int64
# fiyat(TRY)         int64
# dtype: object

# %%
X = df[["kilometre(Km)", "yıl"]]

# %%
y = df["fiyat(TRY)"]
